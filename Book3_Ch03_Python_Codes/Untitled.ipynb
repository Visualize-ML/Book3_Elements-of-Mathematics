# %%
import matplotlib.pyplot as plt
from matplotlib.patches import RegularPolygon, Circle
import numpy as np

# %%
for num_vertices in [3,4,5,6,7,8]:
    
    fig, ax = plt.subplots()
    ax.set_aspect('equal')
    
    hexagon_inner = RegularPolygon((0,0), numVertices=num_vertices, 
                                   radius=1, alpha=0.2, edgecolor='k')
    ax.add_patch(hexagon_inner)
    
    plt.axis('off')
    
    plt.xlim(-1.5,1.5)
    plt.ylim(-1.5,1.5)
    plt.show()

# %%
for num_vertices in [6,8,10,12,14,16]:
    
    fig, ax = plt.subplots()
    ax.set_aspect('equal')
    
    hexagon_inner = RegularPolygon((0,0), numVertices=num_vertices, 
                                   radius=1, alpha=0.2, edgecolor='k')
    ax.add_patch(hexagon_inner)
    
    hexagon_outer = RegularPolygon((0,0), numVertices=num_vertices, 
                                   radius=1/np.cos(np.pi/num_vertices), 
                                   alpha=0.2, edgecolor='k')
    ax.add_patch(hexagon_outer)
    
    circle = Circle((0,0), radius=1, facecolor = 'none', edgecolor='k')
    ax.add_patch(circle)
    
    plt.axis('off')
    
    plt.xlim(-1.5,1.5)
    plt.ylim(-1.5,1.5)
    plt.show()

# %%
n_start = 3
n_stop  = 100
n_array = np.linspace(n_start,n_stop,n_stop-n_start + 1)

pi_lower_b = np.sin(np.pi/n_array)*n_array
pi_upper_b = np.tan(np.pi/n_array)*n_array

fig, ax = plt.subplots()

plt.axhline(y=np.pi, color='r', linestyle='-.')
plt.plot(n_array,pi_lower_b, color = 'b')
plt.plot(n_array,pi_upper_b, color = 'g')
plt.fill_between(n_array, pi_lower_b, pi_upper_b, color = '#DEEAF6')
plt.tight_layout()
plt.xlabel('Number of sides, n')
plt.ylabel('Estimate of $\pi$')
# Out:
# Text(42.847222222222214, 0.5, 'Estimate of $\\pi$')

# %%
import streamlit as st
import matplotlib.pyplot as plt
from matplotlib.patches import RegularPolygon, Circle
import numpy as np

#%%

with st.sidebar:
    num_vertices = st.slider('Number of sides of polygon：',
                             min_value = 4,
                             max_value = 20,
                             step = 1)
    
#%%

fig_1, ax = plt.subplots()
ax.set_aspect('equal')

hexagon_inner = RegularPolygon((0,0), numVertices=num_vertices, 
                               radius=1, alpha=0.2, edgecolor='k')
ax.add_patch(hexagon_inner)

hexagon_outer = RegularPolygon((0,0), numVertices=num_vertices, 
                               radius=1/np.cos(np.pi/num_vertices), 
                               alpha=0.2, edgecolor='k')
ax.add_patch(hexagon_outer)

circle = Circle((0,0), radius=1, facecolor = 'none', edgecolor='k')
ax.add_patch(circle)

plt.axis('off')

plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)
plt.show()

st.pyplot(fig_1)


#%%

n_array = np.linspace(3,num_vertices)

pi_lower_b = np.sin(np.pi/n_array)*n_array
pi_upper_b = np.tan(np.pi/n_array)*n_array

fig_2, ax = plt.subplots()

plt.axhline(y=np.pi, color='r', linestyle='-')
plt.plot(n_array,pi_lower_b, color = 'b')
plt.plot(n_array,pi_upper_b, color = 'g')
plt.fill_between(n_array, pi_lower_b, pi_upper_b, color = '#DEEAF6')
plt.tight_layout()
plt.xlabel('Number of sides, n')
plt.ylabel('Estimate of $\pi$')
plt.xlim((n_array.min(),n_array.max()))

st.pyplot(fig_2)
# Out:
# 2023-05-11 17:50:00.024
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Anaconda3\envs\math\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
# !streamlit run C:\Anaconda3\envs\math\Lib\site-packages\ipykernel_launcher.py
# Out:
# ^C

# %%
# from pathlib import Path
# a = Path(r"C:\Users\yu126\Desktop\ai_data\starve")

# %%
# dir(a)
# Out:
# ['__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__fspath__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__truediv__',
#  '_cached_cparts',
#  '_cparts',
#  '_drv',
#  '_flavour',
#  '_format_parsed_parts',
#  '_from_parsed_parts',
#  '_from_parts',
#  '_hash',
#  '_make_child',
#  '_make_child_relpath',
#  '_parse_args',
#  '_parts',
#  '_pparts',
#  '_root',
#  '_scandir',
#  '_str',
#  'absolute',
#  'anchor',
#  'as_posix',
#  'as_uri',
#  'chmod',
#  'cwd',
#  'drive',
#  'exists',
#  'expanduser',
#  'glob',
#  'group',
#  'hardlink_to',
#  'home',
#  'is_absolute',
#  'is_block_device',
#  'is_char_device',
#  'is_dir',
#  'is_fifo',
#  'is_file',
#  'is_mount',
#  'is_relative_to',
#  'is_reserved',
#  'is_socket',
#  'is_symlink',
#  'iterdir',
#  'joinpath',
#  'lchmod',
#  'link_to',
#  'lstat',
#  'match',
#  'mkdir',
#  'name',
#  'open',
#  'owner',
#  'parent',
#  'parents',
#  'parts',
#  'read_bytes',
#  'read_text',
#  'readlink',
#  'relative_to',
#  'rename',
#  'replace',
#  'resolve',
#  'rglob',
#  'rmdir',
#  'root',
#  'samefile',
#  'stat',
#  'stem',
#  'suffix',
#  'suffixes',
#  'symlink_to',
#  'touch',
#  'unlink',
#  'with_name',
#  'with_stem',
#  'with_suffix',
#  'write_bytes',
#  'write_text']

# %%
# ??a.with_suffix
# Out:
# Signature: a.with_suffix(suffix)
# Source:
#     def with_suffix(self, suffix):
#         """Return a new path with the file suffix changed.  If the path
#         has no suffix, add given suffix.  If the given suffix is an empty
#         string, remove the suffix from the path.
#         """
#         f = self._flavour
#         if f.sep in suffix or f.altsep and f.altsep in suffix:
#             raise ValueError("Invalid suffix %r" % (suffix,))
#         if suffix and not suffix.startswith('.') or suffix == '.':
#             raise ValueError("Invalid suffix %r" % (suffix))
#         name = self.name
#         if not name:
#             raise ValueError("%r has an empty name" % (self,))
#         old_suffix = self.suffix
#         if not old_suffix:
#             name = name + suffix
#         else:
#             name = name[:-len(old_suffix)] + suffix
#         return self._from_parsed_parts(self._drv, self._root,
#                                        self._parts[:-1] + [name])
# File:      c:\anaconda3\envs\math\lib\pathlib.py
# Type:      method

# %%
# for i in a.iterdir():
#     if i.suffix == ".webp":
#         i.rename(i.with_suffix(".jpg"))    
#         print(i)
        # break
# Out:
# C:\Users\yu126\Desktop\ai_data\starve\Ancient Guardian _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Ancient Sentrypede _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Antlion _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Batilisk _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Battlemaster Pugna _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Bearger _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Bee Queen _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Beefalo _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Beefalo _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\BFB _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Blue Whale _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Boaraudience _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Briar Wolf _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Carrat _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Clockwork Bishop _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Clockwork Knight _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Clockwork Rook _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Crab King _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Crabby Hermit _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Critters _ Don't Starve Wiki _ Fandom_10.webp
# C:\Users\yu126\Desktop\ai_data\starve\Critters _ Don't Starve Wiki _ Fandom_7.webp
# C:\Users\yu126\Desktop\ai_data\starve\Critters _ Don't Starve Wiki _ Fandom_8.webp
# C:\Users\yu126\Desktop\ai_data\starve\Critters _ Don't Starve Wiki _ Fandom_9.webp
# C:\Users\yu126\Desktop\ai_data\starve\Crocodog _ Don't Starve Wiki _ Fandom_4.webp
# C:\Users\yu126\Desktop\ai_data\starve\Crocommander _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Damaged Bishop _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Damaged Knight _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Damaged Rook _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Dangling Depth Dweller _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Deadly Brightshade _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Deerclops _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Depths Worm _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Dogfish _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Doydoy _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Dragonfly _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Dung Beetle _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Elder Mandrake _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Ewecus _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Eye of Terror _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Eye of Terror _ Don't Starve Wiki _ Fandom_4.webp
# C:\Users\yu126\Desktop\ai_data\starve\Fishermerm _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Floaty Boaty Knight _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Frog _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Gem Deer _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Giant Grub _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Glommer _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Gnarwail _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Gobbler _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Grainy Transmission _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Grass Gator _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Grass Gekko _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Hippopotamoose _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Horror Hound _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Hound _ Don't Starve Wiki _ Fandom_2.webp
# C:\Users\yu126\Desktop\ai_data\starve\Hutch _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Iron Hulk _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Iron Hulk _ Don't Starve Wiki _ Fandom_4.webp
# C:\Users\yu126\Desktop\ai_data\starve\Klaus _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Koalefant _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Krampus _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Loyal Merm Guard _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Malbatross _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Maxameleon _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Maxwell NPC _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Maxwell _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Meat Bulb (Lureplant) _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Midsummer Cawnival _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Midsummer Cawnival _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Moose_Goose _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Mosling _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Mumsy _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Naked Mole Bat _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\No-Eyed Deer _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Ocean Fishes _ Don't Starve Wiki _ Fandom_23.webp
# C:\Users\yu126\Desktop\ai_data\starve\Ocean Fishes _ Don't Starve Wiki _ Fandom_26.webp
# C:\Users\yu126\Desktop\ai_data\starve\Ocean Fishes _ Don't Starve Wiki _ Fandom_27.webp
# C:\Users\yu126\Desktop\ai_data\starve\Ocean Fishes _ Don't Starve Wiki _ Fandom_29.webp
# C:\Users\yu126\Desktop\ai_data\starve\Ocean Fishes _ Don't Starve Wiki _ Fandom_37.webp
# C:\Users\yu126\Desktop\ai_data\starve\Ocean Fishes _ Don't Starve Wiki _ Fandom_42.webp
# C:\Users\yu126\Desktop\ai_data\starve\Old Beefalo _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Palm Treeguard _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Pangolden _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Peagawk _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Pengull _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Pipton _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Platapine _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Polly Roger's Hat _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Pugalisk _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Quacken _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Queen Womant _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Rhinocebro _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Ro Bin _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Rock Lobster _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Rockjaw _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Sammy _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Scorpeon _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Scorpion _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Sea Hound _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Sea Strider _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Sealnado _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Sharkitten _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Shattered Spider _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Slurtle _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Snortoise _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Spider Monkey _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Spider Warrior _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Spitter _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Stage _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Suspicious Peeper _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Swordfish _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Tiger Shark _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Toadstool _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Treeguard _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Unimplemented Characters _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Unimplemented Characters _ Don't Starve Wiki _ Fandom_2.webp
# C:\Users\yu126\Desktop\ai_data\starve\Unimplemented Characters _ Don't Starve Wiki _ Fandom_3.webp
# C:\Users\yu126\Desktop\ai_data\starve\Unimplemented Characters _ Don't Starve Wiki _ Fandom_5.webp
# C:\Users\yu126\Desktop\ai_data\starve\Unimplemented Characters _ Don't Starve Wiki _ Fandom_7.webp
# C:\Users\yu126\Desktop\ai_data\starve\Vampire Bat _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Varg _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Varglet _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Viper _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Volt Goat _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wagstaff _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Walani _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Walter _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wanda _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Warbucks _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Warly _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Water Beefalo _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Webber _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wendy _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wes _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wheeler _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\White Whale _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wickerbottom _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wigfrid _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wilba _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wilbur _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Willow _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wilson _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Winona _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Winter's Feast _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Woby _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wolfgang _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wonkey _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Woodie _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Woodlegs _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wormwood _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wortox _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Wurt _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\WX-78 _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Yaarctopus _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Year of the Carrat _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Year of the Catcoon _ Don't Starve Wiki _ Fandom.webp
# C:\Users\yu126\Desktop\ai_data\starve\Year of the Catcoon _ Don't Starve Wiki _ Fandom_1.webp
# C:\Users\yu126\Desktop\ai_data\starve\Year of the Varg _ Don't Starve Wiki _ Fandom.webp

# %%
# b = Path(r"C:\Users\yu126\Desktop\ai_data\starve\test.webp")
# b.suffix, b.exists()
# Out:
# ('.webp', False)

# %%
# c = b.with_suffix(".jpg")

# %%
# b.rename(b.with_suffix(".jpg"))
# Out:
# WindowsPath('C:/Users/yu126/Desktop/ai_data/starve/test.jpg')
