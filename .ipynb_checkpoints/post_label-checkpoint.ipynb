# %%
from pathlib import Path
from PIL import Image

# %%
root_path = Path(r"C:\Users\yu126\Downloads\images_labels\creature_pre_proc")

# %%
all_pic = (i for i in root_path.iterdir() if i.is_file() and i.suffix in ".jpg")
# all_pic

# %%
# a = Path(r"C:\Users\yu126\Downloads\images_labels\creature_pre_proc\000 - Copy.txt")

# %%
# ??a.open

# %%
# af = a.open(encoding='u8')
# new_text = af.read().replace("blip: ", "").replace("wdvitgit: ", "")
# new_text

# %%
# ??af.truncate

# %%
img_path = next(all_pic)
ori_text_path = img_path.parent/"bak"/img_path.with_suffix(".txt").name
save_text_path = img_path.with_suffix(".txt")

# %%
img = Image.open(img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
ori_text_path.read_text().replace("blip: ", "").replace("\nwdvitgit: ", "")
# Out:
# 'a cartoon character with a long beard and a knifesolo, 1boy, male focus, axe, beard, leaf, facial hair, weapon'

# %%
# Out:
# ['__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__fspath__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__truediv__',
#  '_cached_cparts',
#  '_cparts',
#  '_drv',
#  '_flavour',
#  '_format_parsed_parts',
#  '_from_parsed_parts',
#  '_from_parts',
#  '_hash',
#  '_make_child',
#  '_make_child_relpath',
#  '_parse_args',
#  '_parts',
#  '_pparts',
#  '_root',
#  '_scandir',
#  '_str',
#  'absolute',
#  'anchor',
#  'as_posix',
#  'as_uri',
#  'chmod',
#  'cwd',
#  'drive',
#  'exists',
#  'expanduser',
#  'glob',
#  'group',
#  'hardlink_to',
#  'home',
#  'is_absolute',
# ...

# %%
ori_text_path = img_path.parent/"bak"/img_path.with_suffix(".txt").name
save_text_path = img_path.with_suffix(".txt")
# img_path.parent, img_path.name, ori_text_path, save_text_path

# %%
edit_text = input()
# save_text_path.open(mode="w", encoding='u8').write(edit_text)
save_text_path.write_text(edit_text)
edit_text
# Out:
#  with glowing eyes and a long horn no humans, glowing eyes, white background, full body, standing
# 96
